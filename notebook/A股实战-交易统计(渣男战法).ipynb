# %%
from winq import *
from winq.selector.stat import stat

db = default(log_level='info')
path = '/Users/luoguochun/Downloads/stock/交易记录.xlsx'

# %%
s_data, w_data = await stat(path=path, db=db, stat_days=10)

# %%
s_data
# Out:
#           代码      名称                买入时间      买入价   n_1    n_2   n_3    n_4  \
# 0   sh688001    华兴源创 2023-04-06 10:20:00   38.136 -2.61  -4.00 -4.84  -0.91
# 1   sh688252     天德钰 2023-04-06 10:18:00   24.185  0.48  -5.15 -3.54   5.31
# 2   sh688277   天智航-U 2023-04-07 10:32:00   17.505 -3.40  -2.43 -1.69  -3.68
# 3   sz300378    鼎捷软件 2023-04-07 10:38:00   22.903 -3.20   0.34  2.65   4.27
# 4   sh688508     芯朋微 2023-04-10 10:00:00   86.826 -2.49  -2.93 -3.72  -0.77
# 5   sz300757    罗博特科 2023-04-10 10:00:00   55.730 -5.01  -5.51 -6.78  -6.75
# 6   sz300468    四方精创 2023-04-11 13:52:00   12.819  4.45   0.94  0.40  -4.91
# 7   sz300413    芒果超媒 2023-04-11 10:18:00   39.806  0.86  -0.52 -3.58 -12.40
# 8   sh688387  信科移动-U 2023-04-12 10:46:00    7.081 -3.97  -3.97 -5.66  -3.69
# 9   sh688192  迪哲医药-U 2023-04-12 09:51:00   50.473  0.17   6.99  7.70   6.99
# 10  sh688192  迪哲医药-U 2023-04-13 10:30:00   51.240  5.39   6.09  5.39   3.88
# ...

# %%
w_data
# Out:
#            n_1           n_2           n_3           n_4           n_5  \
# 0  35.0%(7/20)  33.33%(6/18)  31.25%(5/16)  35.71%(5/14)  41.67%(5/12)
#
#            n_6         n_7         n_8         n_9        n_10
# 0  50.0%(5/10)  37.5%(3/8)  50.0%(3/6)  50.0%(2/4)  50.0%(1/2)
