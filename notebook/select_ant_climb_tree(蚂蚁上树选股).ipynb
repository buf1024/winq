# %%
from winq import *
from winq.selector import strategies, intro
fund, stock, mysql = default(log_level='error')

# %%
data = await stock.load_stock_daily(filter={'code': 'sz002432'})

# %%
import talib

# %%
data['ma55'] = talib.MA(data['close'], timeperiod=55)

# %%
data[:70]
# Out:
#         code trade_date  close   open   high    low       volume  turnover  \
# 0   sz002432 2021-12-24  38.52  34.50  38.52  33.00   81145624.0     16.94
# 1   sz002432 2021-12-23  35.02  38.79  40.00  34.16  108297810.0     22.41
# 2   sz002432 2021-12-22  37.96  37.96  37.96  32.51  110805698.0     23.11
# 3   sz002432 2021-12-21  34.51  34.51  34.51  34.51    2036315.0      0.42
# 4   sz002432 2021-12-20  31.37  30.99  31.37  30.10   23284508.0      4.83
# 5   sz002432 2021-12-17  28.52  26.95  28.52  26.16   74924046.0     15.64
# 6   sz002432 2021-12-16  25.93  27.60  27.60  25.30  120383105.0     24.48
# 7   sz002432 2021-12-15  25.14  23.00  25.14  22.88   55880897.0     11.66
# 8   sz002432 2021-12-14  22.85  21.01  22.85  20.51   94894835.0     19.82
# 9   sz002432 2021-12-13  20.77  18.37  20.77  18.37  106783740.0     22.30
# 10  sz002432 2021-12-10  18.88  19.55  20.15  18.68   89896583.0     18.50
# ...

# %%
for i, x in enumerate((1, 23, 34)):
    print('{}, {}'.format(i, x))
# Out:
# 0, 1
# 1, 23
# 2, 34
