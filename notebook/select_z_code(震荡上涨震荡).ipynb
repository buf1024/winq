# %%
from winq import *
from winq.selector import strategies, intro
fund, stock, mysql = default(log_level='error')
pretty_df(intro('zcode'))
# Out:
# <style  type="text/css" >
# #T_9cc0eeb2_19ee_11ed_a737_186590d57a6brow0_col0,#T_9cc0eeb2_19ee_11ed_a737_186590d57a6brow0_col1{
#             text-align:  left;
#             white-space:  pre-wrap;
#         }</style><table id="T_9cc0eeb2_19ee_11ed_a737_186590d57a6b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >name</th>        <th class="col_heading level0 col1" >doc</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9cc0eeb2_19ee_11ed_a737_186590d57a6blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9cc0eeb2_19ee_11ed_a737_186590d57a6brow0_col0" class="data row0 col0" >test.ZCode</td>
#                         <td id="T_9cc0eeb2_19ee_11ed_a737_186590d57a6brow0_col1" class="data row0 col1" >  名称: Z形态震荡上涨震荡(基于日线)
#   说明: 右侧上涨爬升震荡的股票
#   参数: min_trade_days -- 最小上市天数(默认: 60)
#         right_horizon_days -- 右侧水平震荡的最大天数(默认: 15)
# ...

# %%
strategy = strategies['test.ZCode'](db=stock, test_end_date='20220628')
await strategy.prepare()
data = await strategy.run()
# Out:
# ...
# 统计 sz301190: 100%|██████████| 85/85 [00:06<00:00, 12.46it/s]

# %%
pretty_df(data)
# Out:
# <style  type="text/css" >
# ...

# %%
charts = await strategy.plots(data)

# %%
charts['sh601618'].render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="878ef774413b4c0492d7ee79e78ffb73" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_878ef774413b4c0492d7ee79e78ffb73 = echarts.init(
#                     document.getElementById('878ef774413b4c0492d7ee79e78ffb73'), 'white', {renderer: 'canvas'});
# ...

# %%
strategy.export_to_path('/Users/luoguochun/Downloads/z0628.txt', data)
