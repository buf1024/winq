# %%
from winq import *
from winq.selector import strategies, intro
fund, stock, mysql = default(log_level='error')

# %%
strategy = strategies['test.RightSide'](db=stock, test_end_date='20220210')
await strategy.prepare(min_rise_days=2,  max_down_in_rise=-1,
                       max_up_in_rise=20, max_leg_ratio=33.3,
                       recent_days=10, recent_days_up=8, sort_by='nday_rise')
# await strategy.prepare(min_rise_days=2,  max_down_in_rise=-5,
#                        max_up_in_rise=20, max_leg_ratio=33.3,
#                        recent_days=10, recent_days_up=5, sort_by='nday_rise')
data = await strategy.run()
# Out:
# 处理 sh688261: 100%|██████████| 4693/4693 [01:47<00:00, 43.52it/s]
# 统计 sz002512: 100%|██████████| 155/155 [00:05<00:00, 30.12it/s]

# %%
pretty_df(data)
# Out:
# <style  type="text/css" >
# #T_71985a84_8a67_11ec_8a37_186590d57a6brow0_col0,#T_71985a84_8a67_11ec_8a37_186590d57a6brow0_col1,#T_71985a84_8a67_11ec_8a37_186590d57a6brow0_col2,#T_71985a84_8a67_11ec_8a37_186590d57a6brow0_col3,#T_71985a84_8a67_11ec_8a37_186590d57a6brow0_col4,#T_71985a84_8a67_11ec_8a37_186590d57a6brow0_col5,#T_71985a84_8a67_11ec_8a37_186590d57a6brow0_col6,#T_71985a84_8a67_11ec_8a37_186590d57a6brow0_col7,#T_71985a84_8a67_11ec_8a37_186590d57a6brow0_col8,#T_71985a84_8a67_11ec_8a37_186590d57a6brow1_col0,#T_71985a84_8a67_11ec_8a37_186590d57a6brow1_col1,#T_71985a84_8a67_11ec_8a37_186590d57a6brow1_col2,#T_71985a84_8a67_11ec_8a37_186590d57a6brow1_col3,#T_71985a84_8a67_11ec_8a37_186590d57a6brow1_col4,#T_71985a84_8a67_11ec_8a37_186590d57a6brow1_col5,#T_71985a84_8a67_11ec_8a37_186590d57a6brow1_col6,#T_71985a84_8a67_11ec_8a37_186590d57a6brow1_col7,#T_71985a84_8a67_11ec_8a37_186590d57a6brow1_col8,#T_71985a84_8a67_11ec_8a37_186590d57a6brow2_col0,#T_71985a84_8a67_11ec_8a37_186590d57a6brow2_col1,#T_71985a84_8a67_11ec_8a37_186590d57a6brow2_col2,#T_71985a84_8a67_11ec_8a37_186590d57a6brow2_col3,#T_71985a84_8a67_11ec_8a37_186590d57a6brow2_col4,#T_71985a84_8a67_11ec_8a37_186590d57a6brow2_col5,#T_71985a84_8a67_11ec_8a37_186590d57a6brow2_col6,#T_71985a84_8a67_11ec_8a37_186590d57a6brow2_col7,#T_71985a84_8a67_11ec_8a37_186590d57a6brow2_col8,#T_71985a84_8a67_11ec_8a37_186590d57a6brow3_col0,#T_71985a84_8a67_11ec_8a37_186590d57a6brow3_col1,#T_71985a84_8a67_11ec_8a37_186590d57a6brow3_col2,#T_71985a84_8a67_11ec_8a37_186590d57a6brow3_col3,#T_71985a84_8a67_11ec_8a37_186590d57a6brow3_col4,#T_71985a84_8a67_11ec_8a37_186590d57a6brow3_col5,#T_71985a84_8a67_11ec_8a37_186590d57a6brow3_col6,#T_71985a84
 'hfq_factor': '4.1580734435549000', 'name': '保利联合'}, '21/11/29': {'code': 'sz002037', 'trade_date': '21/11/29', 'close': 6.9, 'open': 6.95, 'high': 7.05, 'low': 6.86, 'volume': 6432100, 'turnover': 1.93, 'hfq_factor': '4.1580734435549000', 'name': '保利联合'}, '21/11/30': {'code': 'sz002037', 'trade_date': '21/11/30', 'close': 7.05, 'open': 6.93, 'high': 7.23, 'low': 6.92, 'volume': 5015901, 'turnover': 1.51, 'hfq_factor': '4.1580734435549000', 'name': '保利联合'}, '21/12/01': {'code': 'sz002037', 'trade_date': '21/12/01', 'close': 7.16, 'open': 7.05, 'high': 7.22, 'low': 7.01, 'volume': 3491601, 'turnover': 1.06, 'hfq_factor': '4.1580734435549000', 'name': '保利联合'}, '21/12/02': {'code': 'sz002037', 'trade_date': '21/12/02', 'close': 7.08, 'open': 7.16, 'high': 7.21, 'low': 7.07, 'volume': 2498935, 'turnover': 0.75, 'hfq_factor': '4.1580734435549000', 'name': '保利联合'}, '21/12/03': {'code': 'sz002037', 'trade_date': '21/12/03', 'close': 7.18, 'open': 7.0 ...

# %%
strategy.export_to_path('/Users/luoguochun/Downloads/右侧上涨10.txt', data)

# %%
import polars as pl

df = pl.read_csv("https://j.mp/iriscsv")
print(df.filter(pl.col("sepal_length") > 5)
      .groupby("species")
      .agg(pl.all().sum())
)
# Out:
# shape: (3, 5)
# ┌────────────┬──────────────┬─────────────┬──────────────┬─────────────┐
# │ species    ┆ sepal_length ┆ sepal_width ┆ petal_length ┆ petal_width │
# │ ---        ┆ ---          ┆ ---         ┆ ---          ┆ ---         │
# │ str        ┆ f64          ┆ f64         ┆ f64          ┆ f64         │
# ╞════════════╪══════════════╪═════════════╪══════════════╪═════════════╡
# │ versicolor ┆ 281.9        ┆ 131.8       ┆ 202.9        ┆ 63.3        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ virginica  ┆ 324.5        ┆ 146.2       ┆ 273.1        ┆ 99.6        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ setosa     ┆ 116.9        ┆ 81.7        ┆ 33.2         ┆ 6.1         │
# └────────────┴──────────────┴─────────────┴──────────────┴─────────────┘

# %%
df.filter(pl.col("sepal_length") > 5).groupby("species").agg(pl.all().sum())
# Out:
# shape: (3, 5)
# ┌────────────┬──────────────┬─────────────┬──────────────┬─────────────┐
# │ species    ┆ sepal_length ┆ sepal_width ┆ petal_length ┆ petal_width │
# │ ---        ┆ ---          ┆ ---         ┆ ---          ┆ ---         │
# │ str        ┆ f64          ┆ f64         ┆ f64          ┆ f64         │
# ╞════════════╪══════════════╪═════════════╪══════════════╪═════════════╡
# │ versicolor ┆ 281.9        ┆ 131.8       ┆ 202.9        ┆ 63.3        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ virginica  ┆ 324.5        ┆ 146.2       ┆ 273.1        ┆ 99.6        │
# ├╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ setosa     ┆ 116.9        ┆ 81.7        ┆ 33.2         ┆ 6.1         │
# └────────────┴──────────────┴─────────────┴──────────────┴─────────────┘

# %%
import akshare as ak
from functools import partial

class A:
    def __init__(self):
        self.tab = {}
    def __getattr__(self, name):
        if name in self.tab:
            return self.tab[name]
        self.tab[name] = partial(self.a, bb=name, coll=name)
        return self.tab[name]
    def a(self, bb, coll, data):
        print(f'{bb}, {coll}, data={data}')
        
a = A()
a.a(1, 2, 3)

f = a.xx
f('a')
#a.xx('abc')
# Out:
# 1, 2, data=3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f58937e0d7b6> in <module>
#      17
#      18 f = a.xx
# ---> 19 f('a')
#      20 #a.xx('abc')
#
# TypeError: a() got multiple values for argument 'bb'

# %%
plot.my_plot(data).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="aff8a8d6befb44468dd81094fe91da6e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_aff8a8d6befb44468dd81094fe91da6e = echarts.init(
#                     document.getElementById('aff8a8d6befb44468dd81094fe91da6e'), 'white', {renderer: 'canvas'});
#                     var kdata={'22/05/24': {'trade_date': '22/05/24', 'open': 999.227, 'high': 1007.811, 'low': 953.564, 'close': 953.564, 'volume': 641211430, 'amount': 15060711000.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/05/25': {'trade_date': '22/05/25', 'open': 942.025, 'high': 957.107, 'low': 934.89, 'close': 952.857, 'volume': 374820020, 'amount': 9760895800.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/05/26': {'trade_date': '22/05/26', 'open': 953.995, 'high': 954.01, 'low': 928.936, 'close': 934.4830000000001, 'volume': 448067020, 'amount': 10821116900.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/05/27': {'trade_date': '22/05/27', 'open': 937.159, 'high': 943.113, 'low': 922.334, 'close': 932.385, 'volume': 489642900, 'amount': 11580991300.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/05/30': {'trade_date': '22/05/30', 'open': 931.535, 'high': 931.944, 'low': 909.9689999999999, 'close': 918.908, 'volume': 436864840, 'amount': 11390972900.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/05/31': {'trade_date': '22/05/31', 'open': 919.675, 'high': 922.078, 'low': 897.706, 'close': 921.122, 'volume': 437529930, 'amount': 11558912000.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/06/01': {'trade_date': '22/06/01', 'open': 918.6469999999999, 'high': 931.471, 'low': 912.187, 'close': 917.0210000000001, 'volume': 395248960, 'amount': 10160624000.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/06/02': {'trade_date': '22/06/02', 'open': 918.814, 'high': 918.814, 'low': 905.075, 'close': 916.416, 'volume': 363437570, 'amount': 9072939100.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/06/06': {'trade_date': '22/06/06', 'open': 915.995, 'high': 935.883, 'low': 915.314, 'close': 933.3330000000001, 'volume': 401583000, 'amount': 10256526000.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/06/07': {'trade_date': '22/06/07', 'open': 932.6510000000001, 'high': 951.878, 'low': 928.535, 'close': 951.865, 'volume': 691570740, 'amount': 15538314000.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/06/08': {'trade_date': '22/06/08', 'open': 950.133, 'high': 950.133, 'low': 926.711, 'close': 935.687, 'volume': 574542320, 'amount': 14353347000.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/06/09': {'trade_date': '22/06/09', 'open': 934.14, 'high': 938.23, 'low': 911.75, 'close': 913.822, 'volume': 415976200, 'amount': 9949660600.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/06/10': {'trade_date': '22/06/10', 'open': 911.698, 'high': 930.8989999999999, 'low': 911.043, 'close': 930.095, 'volume': 425772740, 'amount': 11719607900.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/06/13': {'trade_date': '22/06/13', 'open': 923.08, 'high': 933.525, 'low': 921.331, 'close': 931.929, 'volume': 393780320, 'amount': 9838800300.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/06/14': {'trade_date': '22/06/14', 'open': 923.181, 'high': 926.105, 'low': 898.257, 'close': 922.178, 'volume': 375280340, 'amount': 9241744600.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/06/15': {'trade_date': '22/06/15', 'open': 923.9110000000001, 'high': 937.535, 'low': 923.9069999999999, 'close': 925.46, 'volume': 394136940, 'amount': 10987368400.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/06/16': {'trade_date': '22/06/16', 'open': 925.068, 'high': 944.523, 'low': 925.068, 'close': 936.2660000000001, 'volume': 381356640, 'amount': 10718449700.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/06/17': {'trade_date': '22/06/17', 'open': 930.6210000000001, 'high': 945.904, 'low': 921.623, 'close': 945.388, 'volume': 387013500, 'amount': 12672224700.0, 'concept_code': '308941', 'concept_name': '猴痘概念'}, '22/06/20': {'trade_date': '22/06/20', 'open': 947.404, 'high': 965.953, 'low': 947.2130000000001, 'close': 964.547, 'volume': 493869820, 'amount': 15166853000.0, 'concept_code': '308941', 'concept_ ...

# %%
import akshare as ak

# %%
ak.bond_zh_cov()
# Out:
#        债券代码   债券简称        申购日期    申购代码  申购上限    正股代码  正股简称    正股价    转股价  \
# 0    111008   沿浦转债  2022-11-02  713128   100  605128  上海沿浦  45.30  47.11
# 1    123166   蒙泰转债  2022-11-02  370876   100  300876  蒙泰高新  26.78  26.15
# 2    113063   赛轮转债  2022-11-02  783058   100  601058  赛轮轮胎   8.69   9.04
# 3    123165   回天转债  2022-10-27  370041   100  300041  回天新材  15.17  20.21
# 4    127076   中宠转2  2022-10-25  072891   100  002891  中宠股份  19.67  28.35
# ..      ...    ...         ...     ...   ...     ...   ...    ...    ...
# 746  110227   赤化转债  2007-10-10  733227   100  600227   圣济堂   2.77    NaN
# 747  126006  07深高债  2007-10-09  733548   100  600548   深高速   8.21    NaN
# 748  110971   恒源转债  2007-09-24  733971   100  600971  恒源煤电   7.85    NaN
# 749  110567   山鹰转债  2007-09-05  733567   100  600567  山鹰国际   2.32    NaN
# 750  110026   中海转债  2007-07-02  733026   100  600026  中远海能  16.91    NaN
#
#          转股价值    债现价  转股溢价率 原股东配售-股权登记日  原股东配售-每股配售额       发行规模      中签号发布日  \
# 0     96.1579  100.0   4.00  2022-11-01       4.8000   3.840000  2022-11-04
# 1    102.4092  100.0  -2.35  2022-11-01       3.1250   3.000000  2022-11-04
# 2     96.1283  100.0   4.03  2022-11-01       0.6550  20.089850  2022-11-04
# 3     75.0619  100.0  33.22  2022-10-26       1.9726   8.500000  2022-10-31
# 4     69.3827  100.0  44.13  2022-10-24       2.6148   7.690459  2022-10-27
# ..        ...    ...    ...         ...          ...        ...         ...
# 746       NaN  100.0    NaN  2007-10-09       2.4000   4.500000  2007-10-16
# 747       NaN  100.0    NaN  2007-10-08       1.8000  15.000000  2007-10-15
# 748       NaN  100.0    NaN  2007-09-21       1.0000   4.000000  2007-09-28
# 749       NaN  100.0    NaN  2007-09-04       1.1000   4.700000  2007-09-11
# 750       NaN  100.0    NaN  2007-06-29       0.9000  20.000000  2007-07-06
#
#           中签率        上市时间
# 0         NaN         NaT
# 1         NaN         NaT
# 2         NaN         NaT
# 3    0.002622         NaT
# 4    0.002713         NaT
# ..        ...         ...
# 746  0.158854  2007-10-23
# 747  0.290304  2007-10-30
# 748  5.311774  2007-10-12
# 749  0.496391  2007-09-17
# 750  1.333453  2007-07-12
#
# [751 rows x 18 columns]
